# %% [markdown]
# <a href="https://colab.research.google.com/github/Malvape/pruebass/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls -a ~
# Out:
# .   .bashrc  .config   .jupyter  .launchpadlib	.npm	  .tmux.conf
# ..  .cache   .ipython  .keras	 .local		.profile  .wget-hsts

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-79c50a00-1b59-425b-a707-86cfe9d9606d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79c50a00-1b59-425b-a707-86cfe9d9606d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle

# %%
import os
os.makedirs('/root/.kaggle', exist_ok=True)
# !mv kaggle.json /root/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d arjunbhasin2013/ccdata
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arjunbhasin2013/ccdata
# License(s): CC0-1.0
# ...
#   0% 0.00/340k [00:00<?, ?B/s]
# 100% 340k/340k [00:00<00:00, 106MB/s]

# %%
# !unzip ccdata.zip
# Out:
# Archive:  ccdata.zip
#   inflating: CC GENERAL.csv

# %%
import pandas as pd

df = pd.read_csv('CC GENERAL.csv')
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...
